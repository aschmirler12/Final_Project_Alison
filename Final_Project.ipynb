# %% [markdown]
# ---
#
#
# ---
#
# # Final Project
#
#
# ---
#
# ###Step 1: Preparations
#
# - 1.1 Mounting drive and importing the data
#
# - 1.2 Adding the Rating column into books table
#
# - 1.3 Cleaning the data and making it ready for use
#
# - 1.4 Clearing each column
#
# ###Step 2: Add description column
# - Adding the column with the description from Google Books API and loading it into a CSV
#
# ### Step 3: Add Author table
#
# - 3.1. Create table and add description and image columns
# - 3.2. Use Wikipedia API to extract description and Image for each author
# - 3.3. Add a column showing how many books the author wrote
#
#
# ### Step 4: Functions for dataset query
#
# - 4.1 Function to implement the search bar
#
# ### Step 5: Implement Login based on User Table
# - 5.1 Make User DataFrame
#
# - 5.2 Register
#
# - 5.3 Login using the information in the user table
#
# ---
#
#
# ---

# %% [markdown]
# # Step 1: Preparations
# 1.1 Mount drive and import the data
#
# 1.2 Clean data

# %% [markdown]
# ## 1.1 Mounting drive and importing the data

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# Books DataFrame:

# %%
import pandas as pd
import chardet

with open('BX-Books.csv', 'rb') as file:
    result = chardet.detect(file.read())

# %%
df = pd.read_csv('BX-Books.csv', encoding=result['encoding'])
df
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377  0192126040                        Republic (World's Classics)
# 271378  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author  Year-Of-Publication  \
# 0         Mark P. O. Morford               2002.0
# ...

# %% [markdown]
# ## 1.2 Adding the rating column
# - rating column will be the average rating of each book based on BX-Book-Ratings.csv

# %%
with open('BX-Book-Ratings.csv', 'rb') as file:
    result = chardet.detect(file.read())

# %%
df_ratings = pd.read_csv('BX-Book-Ratings.csv', encoding=result['encoding'],delimiter=";")
df_ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
df_ratings = df_ratings[df_ratings['ISBN'].str.contains(r'^\d{9}[\d|X]$', na=False)]
df_ratings
# Out:
#          User-ID        ISBN  Book-Rating
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1149774   276704  0876044011            0
# 1149775   276704  1563526298            9
# 1149776   276706  0679447156            0
# 1149777   276709  0515107662           10
# 1149778   276721  0590442449           10
#
# [1137806 rows x 3 columns]

# %%
# Average book rating for each ISBN
df_ratings = df_ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
df_ratings = df_ratings[df_ratings['Book-Rating'] > 5].sort_values(by='Book-Rating',ascending=False)
df_ratings
# Out:
#               ISBN  Book-Rating
# 331033  9998914140    10.000000
# 257592  1571290532    10.000000
# 117883  0465067840    10.000000
# 117882  046506776X    10.000000
# 257578  157120041X    10.000000
# ...            ...          ...
# 127333  0552137030     5.032258
# 164316  0679886370     5.027778
# 82905   0393312836     5.019231
# 147093  0618002219     5.014286
# 52965   0345339681     5.007117
#
# [80740 rows x 2 columns]

# %% [markdown]
# ## 1.3 Cleaning the data and preparing it for use

# %% [markdown]
# Looking at the data, all columns are relevant to the website:
# - ISBN: used to search for books to retrieve useful information
# - Book Title
# - Book Author: used to search for authors to retrieve useful information
# - Year of Publication
# - Publisher: could be added as an information above the description
# - Image-URL: comes in 3 different sizes. All three sizes may be needed when developing the website.

# %%
print(f"Data type information: ")
df.info()
# Out:
# Data type information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271379 entries, 0 to 271378
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271379 non-null  object
#  1   Book-Title           271379 non-null  object
#  2   Book-Author          271378 non-null  object
#  3   Year-Of-Publication  271357 non-null  float64
#  4   Publisher            271377 non-null  object
#  5   Image-URL-S          271379 non-null  object
#  6   Image-URL-M          271379 non-null  object
#  7   Image-URL-L          271376 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 16.6+ MB

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# ISBN                    0
# Book-Title              0
# Book-Author             1
# Year-Of-Publication    22
# Publisher               2
# Image-URL-S             0
# Image-URL-M             0
# Image-URL-L             3
# dtype: int64

# %%
# Clear ISBN column
df = df[df['ISBN'].str.contains(r'^\d{9}[\d|X]$', na=False)]
df
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377  0192126040                        Republic (World's Classics)
# 271378  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author  Year-Of-Publication  \
# 0         Mark P. O. Morford               2002.0
# ...

# %%
# Delete data with null values for publication date
df[df['Year-Of-Publication'].isnull()]
df.dropna(subset=['Year-Of-Publication'],inplace=True)
df
# Out:
# <ipython-input-12-7ad27e241629>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['Year-Of-Publication'],inplace=True)
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# ...

# %%
df.reset_index(inplace=True)
df.rename(columns={'index': 'ID'}, inplace=True)
df
# Out:
# <ipython-input-13-bd3785ea0e96>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'index': 'ID'}, inplace=True)
#             ID        ISBN                                         Book-Title  \
# 0            0  0195153448                                Classical Mythology
# 1            1  0002005018                                       Clara Callan
# 2            2  0060973129                               Decision in Normandy
# 3            3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4            4  0393045218                             The Mummies of Urumchi
# ...        ...         ...                                                ...
# 270823  271374  0440400988                         There's a Bat in Bunk Five
# ...

# %% [markdown]
# We only recommend the books that have a good rating, so joining the table with a rating above 5 and the Books table, we get the final dataframe that is ready to get cleaned.

# %%
# Join the two tables to add the Rating column
df = pd.merge(df,df_ratings,on='ISBN')[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher','Book-Rating','Image-URL-S','Image-URL-M','Image-URL-L']]
df
# Out:
#              ISBN                                         Book-Title  \
# 0      1567407781       The Witchfinder (Amos Walker Mystery Series)
# 1      0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 2      0689821166                           Flood : Mississippi 1927
# 3      3404921038                               Wie Barney es sieht.
# 4      0245542957                                  Pacific Northwest
# ...           ...                                                ...
# 62322  3548740146        Wicca. Eine Einf??¼hrung in wei????e Magie.
# 62323  381440176X  Ein Fall f??¼r TKKG, Bd.50, Sklaven f??¼r Wutawia
# 62324  0395264707                                         Dreamsnake
# 62325  1845170423                                  Cocktail Classics
# 62326  0440400988                         There's a Bat in Bunk Five
#
#                 Book-Author  Year-Of-Publication  \
# 0         Loren D. Estleman               1998.0
# ...

# %% [markdown]
# ## 1.4 Clearing each column using a regex/ validation of data:

# %% [markdown]
# First, change the datatypes of each column and replace the name

# %%
df['Year-Of-Publication'] = df['Year-Of-Publication'].astype(int)
df['Book-Rating'] = df['Book-Rating'].astype(int)

new_column_names = {'Book-Title': 'Title', 'Book-Author': 'Author', 'Book-Rating': 'Rating'}
df.rename(columns=new_column_names, inplace=True)

df
# Out:
#              ISBN                                              Title  \
# 0      1567407781       The Witchfinder (Amos Walker Mystery Series)
# 1      0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 2      0689821166                           Flood : Mississippi 1927
# 3      3404921038                               Wie Barney es sieht.
# 4      0245542957                                  Pacific Northwest
# ...           ...                                                ...
# 62322  3548740146        Wicca. Eine Einf??¼hrung in wei????e Magie.
# 62323  381440176X  Ein Fall f??¼r TKKG, Bd.50, Sklaven f??¼r Wutawia
# 62324  0395264707                                         Dreamsnake
# 62325  1845170423                                  Cocktail Classics
# 62326  0440400988                         There's a Bat in Bunk Five
#
#                      Author  Year-Of-Publication  \
# 0         Loren D. Estleman                 1998
# ...

# %% [markdown]
# ### a. ISBN column

# %%
# Check if IBSN is unique and set it as index
df['ISBN'].is_unique
# Out:
# True

# %% [markdown]
# ### b. String columns (Book-Title, Book-Author, Publisher)

# %% [markdown]
# Function that creates a new dataframe containins the rows that only have ascii encoding.

# %%
import re

def clear_column(col:str,df:pd.DataFrame) -> pd.DataFrame:
  """ returns a dataframe containing only rows that are ascii encoded"""
  ascii_rows = []

  for index, title in df[col].items():
      result = chardet.detect(str(title).encode())
      if result['encoding'] == 'ascii':
          ascii_rows.append(index)

  new_df = df.loc[ascii_rows]
  return new_df

# %%
df = clear_column('Title',df)
df = clear_column('Author',df)
df = clear_column('Publisher',df)
df
# Out:
#              ISBN                                              Title  \
# 0      1567407781       The Witchfinder (Amos Walker Mystery Series)
# 1      0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 2      0689821166                           Flood : Mississippi 1927
# 4      0245542957                                  Pacific Northwest
# 5      0394743741                                The yawning heights
# ...           ...                                                ...
# 62320  3453065123  Ich war Hitlerjunge Salomon. ( erlebt und erfa...
# 62321  3525335423                Das Deutsche Kaiserreich 1871-1918.
# 62324  0395264707                                         Dreamsnake
# 62325  1845170423                                  Cocktail Classics
# 62326  0440400988                         There's a Bat in Bunk Five
#
#                      Author  Year-Of-Publication  \
# 0         Loren D. Estleman                 1998
# ...

# %%
pattern = r'&(\w)*(;)*|[\\"]'
df['Publisher'] = df['Publisher'].str.replace(pattern, '&')
df['Title'] = df['Title'].str.replace(pattern, '')
df['Author'] = df['Author'].str.replace('[^a-zA-Z\s\.]', '')
df['Author'] = df['Author'].str.title()
df
# Out:
# <ipython-input-19-da7fc5f466ae>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Publisher'] = df['Publisher'].str.replace(pattern, '&')
# <ipython-input-19-da7fc5f466ae>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Title'] = df['Title'].str.replace(pattern, '')
# <ipython-input-19-da7fc5f466ae>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Author'] = df['Author'].str.replace('[^a-zA-Z\s\.]', '')
#              ISBN                                              Title  \
# 0      1567407781       The Witchfinder (Amos Walker Mystery Series)
# 1      0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 2      0689821166                           Flood : Mississippi 1927
# 4      0245542957                                  Pacific Northwest
# ...

# %% [markdown]
# ### c. Year-Of-Publication Column

# %%
import numpy as np

condition = (df['Year-Of-Publication'] < 1000) | (df['Year-Of-Publication'] > 2023)
df.loc[condition, 'Year-Of-Publication'] = np.nan

df
# Out:
#              ISBN                                              Title  \
# 0      1567407781       The Witchfinder (Amos Walker Mystery Series)
# 1      0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 2      0689821166                           Flood : Mississippi 1927
# 4      0245542957                                  Pacific Northwest
# 5      0394743741                                The yawning heights
# ...           ...                                                ...
# 62320  3453065123  Ich war Hitlerjunge Salomon. ( erlebt und erfa...
# 62321  3525335423                Das Deutsche Kaiserreich 1871-1918.
# 62324  0395264707                                         Dreamsnake
# 62325  1845170423                                  Cocktail Classics
# 62326  0440400988                         There's a Bat in Bunk Five
#
#                      Author  Year-Of-Publication  \
# 0         Loren D. Estleman               1998.0
# ...

# %% [markdown]
# ## 1.5 Selecting only top rated books

# %%
df_top = df.sort_values(by='Rating',ascending=False).head(180)

# %% [markdown]
# # Step 2: Add description column

# %%
import requests
import json
import time

url = "https://www.googleapis.com/books/v1/volumes"
api_key = input("API Key:")

for i in df_top['ISBN']:

  params = {
      'q': 'isbn:' + i,
      'key': api_key
  }

  response = requests.get(url, params=params)
  data = response.json()
  try:
    if data['totalItems'] == 0:
      df_top = df_top.drop(df_top.loc[df_top['ISBN'] == i].index)
    else:
      description = data['items'][0]['volumeInfo'].get('description', '')
      df_top.loc[df_top['ISBN'] == i, 'Description'] = description
  except KeyError:
    df_top = df_top.drop(df_top.loc[df_top['ISBN'] == i].index)
  time.sleep(0.05)

df_top
# Out:
# API Key:AIzaSyC4BZEZ5igdJRMzXOFDj005XTAIofTrB1A
#              ISBN                                              Title  \
# 20964  1901289060                      Encyclopedia of Herbs  Spices
# 19959  0385231180  Starring Mothers: 30 Portraits of Accomplished...
# 19968  0307244105  Seashells of the World: A Guide to the Better-...
# 19967  0810944731                                   Paul J. Stankard
# 19966  0590438492                    Buried in Ice (Time Quest Book)
# ...           ...                                                ...
# 20026  0207172129                Neglected poems and other creatures
# 20021  0964595737  The Beaded Watchband Book: Techniques for Bead...
# 51241  0330393103                            Saddam: The Secret Life
# 51243  0898159652         A Biblical Feast, Foods from the Holy Land
# 19704  0709048513        Hedge Witch: A Guide to Solitary Witchcraft
#
#                     Author  Year-Of-Publication  \
# ...

# %%
df_top.reset_index(drop=True, inplace=True)
df_top.rename(columns={'index': 'ID'}, inplace=True)
df_top
# Out:
#            ISBN                                              Title  \
# 0    1901289060                      Encyclopedia of Herbs  Spices
# 1    0385231180  Starring Mothers: 30 Portraits of Accomplished...
# 2    0307244105  Seashells of the World: A Guide to the Better-...
# 3    0810944731                                   Paul J. Stankard
# 4    0590438492                    Buried in Ice (Time Quest Book)
# ..          ...                                                ...
# 96   0207172129                Neglected poems and other creatures
# 97   0964595737  The Beaded Watchband Book: Techniques for Bead...
# 98   0330393103                            Saddam: The Secret Life
# 99   0898159652         A Biblical Feast, Foods from the Holy Land
# 100  0709048513        Hedge Witch: A Guide to Solitary Witchcraft
#
#                   Author  Year-Of-Publication  \
# 0           Linda Fraser                  NaN
# 1            Jill Barber               1987.0
# ...

# %% [markdown]
# ### Export books table to CSV

# %%
df_top.to_csv('Books.csv', sep=';', header=True, index=True)

# %% [markdown]
# # Step 3: Make an Author table

# %% [markdown]
# ### 3.1. Create table and add description and image columns

# %%
df_authors = df_top['Author'].reset_index()
df_authors['Description'] = ''
df_authors['Image'] = ''
df_authors
# Out:
#      index               Author Description Image
# 0        0         Linda Fraser
# 1        1          Jill Barber
# 2        2     R. Tucker Abbott
# 3        3  Ulysses Grant Dietz
# 4        4         Owen Beattie
# ..     ...                  ...         ...   ...
# 96      96      Barry Humphries
# 97      97      Wendy S. Conner
# 98      98         Con Coughlin
# 99      99          Kitty Morse
# 100    100             Rae Beth
#
# [101 rows x 4 columns]

# %% [markdown]
# ### 3.2. Use Wikipedia API to extract description and Image for each author

# %%
import requests

for i in df_authors['Author']:
    base_url = 'https://en.wikipedia.org/w/api.php'
    params = {
        'action': 'query',
        'format': 'json',
        'prop': 'extracts|pageimages',
        'exintro': '',
        'explaintext': '',
        'titles': i
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    # Get the page ID of the author
    page_id = next(iter(data['query']['pages'].keys()))

    try:
      desc = data['query']['pages'][page_id]['extract']
      img = data['query']['pages'][page_id]['thumbnail']['source']
      df_authors.loc[df_authors['Author'] == i, 'Description'] = desc
      df_authors.loc[df_authors['Author'] == i, 'Image'] = img
    except:
      continue

# %%
df_authors.replace('',np.nan,inplace=True)
df_authors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        101 non-null    int64
#  1   Author       101 non-null    object
#  2   Description  19 non-null     object
#  3   Image        19 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
df_authors
# Out:
#      index               Author  \
# 0        0         Linda Fraser
# 1        1          Jill Barber
# 2        2     R. Tucker Abbott
# 3        3  Ulysses Grant Dietz
# 4        4         Owen Beattie
# ..     ...                  ...
# 96      96      Barry Humphries
# 97      97      Wendy S. Conner
# 98      98         Con Coughlin
# 99      99          Kitty Morse
# 100    100             Rae Beth
#
#                                            Description  \
# 0                                                  NaN
# 1    Jill Barber (born February 6, 1980) is a Canad...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 96   John Barry Humphries  (17 February 1934 – 22 A...
# 97                                                 NaN
# 98                                                 NaN
# ...

# %% [markdown]
# ### 3.3. Add a column showing how many books the author wrote

# %%
df_auth_count=df_top.groupby('Author')['Title'].count().reset_index()
df_authors = pd.merge(df_auth_count,df_authors,on='Author')[['index','Author','Description','Image','Title']]
df_authors.rename(columns={'index':'ID','Title':'No_Books'},inplace=True)

# %%
df_authors
# Out:
#      ID            Author                                        Description  \
# 0    48      Ahdaf Soueif  Ahdaf Soueif (Arabic: أهداف سويف; born 23 Marc...
# 1    11  Alfred Byrd Graf  Alfred Byrd Graf (November 23, 1901 – December...
# 2    12   Alice Muncaster                                                NaN
# 3    36        Ani Afshar                                                NaN
# 4    79       Arlene Alda                                                NaN
# ..   ..               ...                                                ...
# 96   32     Vicki Willder                                                NaN
# 97   18     Wayne Swanson                                                NaN
# 98   23      Wendy Conner                                                NaN
# 99   97   Wendy S. Conner                                                NaN
# 100  46    William E. Rae                                                NaN
#
# ...

# %%
df_authors.to_csv('Authors.csv', sep=';', header=True, index=True)

# %% [markdown]
# # Step 4: Functions for dataset query

# %% [markdown]
# ### 4.1 Function to implement the search bar

# %%
def search_bar(search,df):
  df = df.astype(str)

  filtered_df = df[df.applymap(lambda x: search in str(x)).any(axis=1)]
  return filtered_df

# %%
while True:
  option = input("""Search for:
  1. Authors
  2. Books
  3. Exit
  Option := """)

  dict_options = {
      "1": df_authors,
      "2": df_top
  }

  if option in dict_options:
    search = input("Search: ")
    display(search_bar(search,dict_options[option]))
  elif option == "3":
    break
  else:
    print("No valid option. ")

# %% [markdown]
# # Step 5: Implement Login based on User Table

# %% [markdown]
# 5.1 Make User DataFrame

# %%
with open('BX-Users.csv', 'rb') as file:
    result = chardet.detect(file.read())

df_users = pd.read_csv('BX-Users.csv', encoding=result['encoding'],delimiter=";")
df_users

# %%
split_data = df_users['Location'].str.split(',', expand=True)
df_users['city'] = split_data[0]
df_users['region'] = split_data[1]
df_users['country'] = split_data[2]
# df_users = df.drop('Location', axis=1)

df_users['Email'] = ''
df_users['Password'] = ''

# %% [markdown]
# ### 5.2 Register

# %%
email = input("Enter your e-mail: ")
country = input("Country: ")
age = input("Age: ")
password1 = input("Password: ")
password2 = input("Confirm Password: ")
if password1 == password2:
  pass
else:
  print("Try again.")

#todo: encrypt password
new_row = {'Email': email, 'Country': country, 'Age': age, 'Password': password1}

df_users = df_users.append(new_row, ignore_index=True)
df_users

# %% [markdown]
# ### 5.3 Login using the information in the user table

# %%
email = input("Enter your e-mail: ")
